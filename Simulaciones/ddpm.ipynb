# %% [markdown]
# # <center>Modelo de difusión</center>

# %%
import torch
import tqdm
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import plotly.graph_objects as go

from sklearn.datasets import make_swiss_roll

torch.manual_seed(42)
device = torch.device('cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu')
print(f'Device: {device}.')
# Out:
# Device: cuda.

# %% [markdown]
# ## Datos de entrenamiento

# %%
def create_dataset(n=10000):
    x, _ = make_swiss_roll(n_samples=n, noise=0.5)
    x = x[:, [0, 2]]
    x = (x - x.mean()) / x.std()
    return torch.tensor(x, dtype=torch.float32)

data_points = create_dataset()
dataset = TensorDataset(data_points)
dataloader = DataLoader(dataset, batch_size=4096, shuffle=True)

# %% [markdown]
# ## Clase `DDPM`

# %%
class DDPM:

    def __init__(self, diffusion_steps=100, scheduler_shift=0.008):
        self.diffusion_steps = diffusion_steps
        timesteps = torch.arange(self.diffusion_steps, dtype=torch.float32, device=device)
        schedule = torch.cos((timesteps / self.diffusion_steps + scheduler_shift) / (1 + scheduler_shift) * torch.pi / 2)**2
        self.alphas_bar = schedule / schedule[0]
        self.betas = 1 - self.alphas_bar / torch.cat([self.alphas_bar[:1], self.alphas_bar[:-1]])
        self.alphas = 1 - self.betas

    def add_noise(self, x, t):
        epsilon = torch.randn_like(x)
        alpha_t = self.alphas_bar[t].view(-1, 1)
        noised = torch.sqrt(alpha_t) * x + torch.sqrt(1 - alpha_t) * epsilon
        return noised, epsilon

    def train_model(self, model, dataloader, optimizer, epochs):
        model.to(device)
        model.train()
        loss_fn = nn.MSELoss()
        scheduler = torch.optim.lr_scheduler.LinearLR(optimizer, start_factor=1.0, end_factor=0.01, total_iters=epochs)

        try:
            progressbar = tqdm.trange(epochs)
            for epoch in progressbar:
                epoch_loss = 0

                for x, in dataloader:

                    x = x.to(device)
                    batch_size = x.shape[0]

                    # Inyección de ruido:
                    timesteps = torch.randint(0, self.diffusion_steps, (batch_size,), device=device)
                    noised, epsilon = self.add_noise(x, timesteps)

                    # Predicción:
                    predicted_noise = model(noised, timesteps.float().unsqueeze(1))
                    loss = loss_fn(predicted_noise, epsilon)
                    epoch_loss += loss.item()

                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                scheduler.step()
                epoch_loss /= len(dataloader)
                progressbar.set_postfix(epoch_loss=epoch_loss)

        except KeyboardInterrupt:
            print('Entrenamiento interrumpido.')

    def generate_samples(self, model, nsamples):
        model.eval()

        with torch.no_grad():
            x = torch.randn(nsamples, model.nfeatures, device=device)

            for t in range(self.diffusion_steps - 1, 0, -1):
                t_tensor = torch.full((nsamples, 1), t, device=device)
                predicted_noise = model(x, t_tensor)

                alpha_t = self.alphas[t]
                alpha_bar_t = self.alphas_bar[t]
                x = (1 / torch.sqrt(alpha_t)) * (x - ((1 - alpha_t) / torch.sqrt(1 - alpha_bar_t)) * predicted_noise)

                if t > 1:
                    x += torch.sqrt(self.betas[t]) * torch.randn_like(x)

            return x.cpu()

# %% [markdown]
# ## Entrenamiento y generación de muestras

# %% [markdown]
# ### Red neuronal

# %%
class DiffusionNetwork(nn.Module):
    def __init__(self, nfeatures, nblocks=2, nunits=64):
        super().__init__()
        self.nfeatures = nfeatures
        self.model = nn.Sequential(
            nn.Linear(nfeatures + 1, nunits),
            *[nn.Sequential(nn.Linear(nunits, nunits), nn.ReLU()) for _ in range(nblocks)],
            nn.Linear(nunits, nfeatures)
        )

    def forward(self, x, t):
        return self.model(torch.cat([x, t], dim=1))

# %% [markdown]
# ### Entrenamiento

# %%
model = DiffusionNetwork(nfeatures=2, nblocks=6)
optimizer = optim.Adam(model.parameters())

ddpm = DDPM()
ddpm.train_model(model, dataloader, optimizer, epochs=1000)
# Out:
# 100%|██████████| 1000/1000 [01:33<00:00, 10.67it/s, epoch_loss=0.424]

# %% [markdown]
# ### Generación de muestras

# %%
def plot_new_samples(new_points):
    fig = go.Figure()

    fig.add_trace(go.Scatter(x=data_points[:, 0], y=data_points[:, 1],
                             mode='markers', name='Datos de entrenamiento',
                             marker=dict(color='blue', opacity=0.1)))

    fig.add_trace(go.Scatter(x=new_points[:, 0], y=new_points[:, 1],
                             mode='markers', name='Muestras generadas',
                             marker=dict(color='red', opacity=0.7)))

    fig.update_layout(
        width=1000,
        height=500,
        plot_bgcolor='white',
        xaxis=dict(visible=False),
        yaxis=dict(visible=False))

    fig.show()
    fig.write_image('images/dm/ddpm_samples.pdf')

# %%
samples = ddpm.generate_samples(model, 1000)
plot_new_samples(samples)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
